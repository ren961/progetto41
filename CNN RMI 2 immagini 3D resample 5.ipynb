# %% [markdown]
# ## Installazione pacchetti e database

# %% [markdown]
# Installazione pacchetto torchio per la gestione delle immagini mediche

# %%
# !pip install torchio
# Out:
# Requirement already satisfied: torchio in /usr/local/lib/python3.10/dist-packages (0.19.1)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.10/dist-packages (from torchio) (1.2.14)
# Requirement already satisfied: SimpleITK!=2.0.*,!=2.1.1.1 in /usr/local/lib/python3.10/dist-packages (from torchio) (2.2.1)
# Requirement already satisfied: humanize in /usr/local/lib/python3.10/dist-packages (from torchio) (4.7.0)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (from torchio) (4.0.2)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from torchio) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from torchio) (1.10.1)
# Requirement already satisfied: torch>=1.1 in /usr/local/lib/python3.10/dist-packages (from torchio) (2.0.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchio) (4.66.1)
# Requirement already satisfied: typer[all] in /usr/local/lib/python3.10/dist-packages (from torchio) (0.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.1->torchio) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.1->torchio) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.1->torchio) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.1->torchio) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1->torchio) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1->torchio) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.1->torchio) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.1->torchio) (16.0.6)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated->torchio) (1.14.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from nibabel->torchio) (23.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel->torchio) (67.7.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer[all]->torchio) (8.1.7)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from typer[all]->torchio) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]->torchio) (1.5.3)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]->torchio) (13.5.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]->torchio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]->torchio) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.1->torchio) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.1->torchio) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]->torchio) (0.1.2)

# %% [markdown]
# Creazione collegamento a google drive in cui sono salvate le immagini

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Installazione dei pacchetti necessari al programma

# %%
import os
import torch
import torchvision
import tarfile
import multiprocessing
import pandas as pd
import torch.nn as nn
import numpy as np
import os.path

import torchio as tio
import torch.nn.functional as F
import torchvision.transforms as tt
from torch.utils.data import random_split
from torch.utils.data.dataloader import DataLoader

from IPython import display

"""from torchvision.utils import make_grid
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

matplotlib.rcParams['figure.facecolor'] = '#ffffff'"""
# Out:
# "from torchvision.utils import make_grid\nimport matplotlib\nimport matplotlib.pyplot as plt\n%matplotlib inline\n\nmatplotlib.rcParams['figure.facecolor'] = '#ffffff'"

# %%
import os
import torch
import torchvision
import tarfile
import pandas as pd
import torch.nn as nn
import numpy as np
import os.path
import shutil
import torchio as tio
import torch.nn.functional as F
import torchvision.transforms as tt
from torch.utils.data import random_split
from torch.utils.data.dataloader import DataLoader
from torchvision.utils import make_grid
import matplotlib
import matplotlib.pyplot as plt
import nibabel as nib
# %matplotlib inline

matplotlib.rcParams['figure.facecolor'] = '#ffffff'

# %% [markdown]
# Importazione del file csv in cui sono presenti tutti gli ID dei pazienti con i rispettivi overall survival (0 < 450 gg e 1 >= 450 gg)

# %%
df = pd.read_csv('/content/drive/MyDrive/Tesi/Progetto/informazioni_pazienti.csv', index_col = 'ID')
print(df)
# Out:
#                     OS
# ID
# UPENN-GBM-00002_11   0
# UPENN-GBM-00006_11   1
# UPENN-GBM-00008_11   1
# UPENN-GBM-00009_11   1
# UPENN-GBM-00011_11   1
# ...                 ..
# UPENN-GBM-00597_11   0
# UPENN-GBM-00601_11   0
# %% [markdown]
# Lista in cui sono presenti tutti i soggetti (contenenti l'immagine e l'overall survival)

# %%
for current in patients_list:
  image_path = '/content/drive/MyDrive/Tesi/Progetto/dataset/' + current + '/' + current+'_img.nii.gz'
  image_name = current

for current in patients_list:
    subject_dict = {'images': tio.ScalarImage('/content/drive/MyDrive/Tesi/Progetto/dataset/' + current + '/' + current+'_img.nii.gz'),
                    'ImagesName': image_name ,#aggiunto per bilanciamento
                    'OS':  df.loc[current, 'OS']
                   }
    subject = tio.Subject(subject_dict)
    subjects_list.append(subject)

# %%
len(subjects_list)
# Out:
# 334

# %% [markdown]
# Creazione del dataset

# %%
subject_dataset = tio.SubjectsDataset(subjects_list)
subject_dataset[0].images.plot()
print('\nInfo paziente "0": ', subject_dataset[0])
print('\nShape: ', subject_dataset[0].images.shape)
print('\nSize images: ', subject_dataset[0].images.spacing)
print('\nDimensione dataset: ', len(subject_dataset))
# Out:
# Info paziente "0":  Subject(Keys: ('images', 'ImagesName', 'OS'); images: 1)
#
# Shape:  (6, 150, 200, 155)
#
# Size images:  (1.0, 1.0, 1.0)
#
# Dimensione dataset:  334

# %% [markdown]
# Funzioni di trasformazioni da applicare ai vari set (richiedono troppe risorse, quindi sono solo state normalizzate)

# %%
training_Transform = tio.Compose([
    tio.ToCanonical(),
    tio.Resample(5),
    tio.RandomFlip(),
    #tio.RandomNoise(p = 0.2),
    #tio.RandomMotion(p = 0.2),
    #tio.EnsureShapeMultiple(16, method = 'pad')
])

val_test_Transform = tio.Compose([
    tio.ToCanonical(),
    tio.Resample(5),
    #tio.EnsureShapeMultiple(16, method = 'pad')
])

# %% [markdown]
# Separazione del dataset in training (70%), validation (20%) e testing set (10%) applicando le rispettive trasformazioni

# %%
val_size = int(round(len(patients_list)*0.2))
train_size = int(round(len(patients_list)*0.7))
test_size = int(round(len(patients_list)*0.1))

random_seed = 11
torch.manual_seed(random_seed)
train_subjs, val_subjs, test_subjs = random_split(subject_dataset, [train_size, val_size, test_size])

train_ds = tio.SubjectsDataset(train_subjs, transform = training_Transform)
val_ds = tio.SubjectsDataset(val_subjs, transform = val_test_Transform)
test_ds = tio.SubjectsDataset(test_subjs, transform = val_test_Transform)

print('Training set: ', len(train_ds), ' pazienti')
print('Validation set: ', len(val_ds), ' pazienti')
print('Testing set: ', len(test_ds), ' pazienti')
# Out:
# Training set:  234  pazienti
# Validation set:  67  pazienti
# Testing set:  33  pazienti

# %%
train_ds[0].images.shape
# Out:
# (6, 30, 40, 31)

# %%
train_ds[0].plot()

# %%
class_0_indices = []
class_1_indices = []
for current in train_ds:
    labels = current['OS']
    inputs = current['images'][tio.DATA]
    name = current['ImagesName']

    if ( labels == 0):
        class_0_indices.append(name)
    else:
      class_1_indices.append(name)

print(len(class_0_indices))
print(len(class_1_indices))

class_0_size=len(class_0_indices)
class_1_size=len(class_1_indices)
# Out:
# 141
# 93

# %%
subjects_train_0 = []
for current in class_0_indices:
  image_path = '/content/drive/MyDrive/Tesi/Progetto/dataset/' + current + '/' + current+'_img.nii.gz'
  image_name = current

  subject_dict = {'images': tio.ScalarImage('/content/drive/MyDrive/Tesi/Progetto/dataset/' + current + '/' + current+'_img.nii.gz'),
                 'ImagesName': image_name ,
                 'OS': df.loc[current, 'OS']
                 }
  subject = tio.Subject(subject_dict)
  subjects_train_0.append(subject)

# %%
subjects_train_1 = []
for current in class_1_indices:
  image_path = '/content/drive/MyDrive/Tesi/Progetto/dataset/' + current + '/' + current+'_img.nii.gz'
  image_name = current

  subject_dict = {'images': tio.ScalarImage('/content/drive/MyDrive/Tesi/Progetto/dataset/' + current + '/' + current+'_img.nii.gz'),
                 'ImagesName': image_name ,
                 'OS': df.loc[current, 'OS']
                 }
  subject = tio.Subject(subject_dict)
  subjects_train_1.append(subject)

# %%
min_class = min(len(class_0_indices), len(class_1_indices))
print (min_class)
min_class_indices = class_0_indices if len(class_0_indices) == min_class else class_1_indices

random_seed = 11
torch.manual_seed(random_seed)
train_subjs_0, _ = random_split(subjects_train_0, [min_class, class_0_size - min_class])
train_subjs_1, _ = random_split(subjects_train_1, [min_class, class_1_size - min_class])

train_subjs_bilanciato = tio.SubjectsDataset(train_subjs_0 + train_subjs_1, transform=training_Transform)
# Out:
# 93

# %%
batch_size=10

# %%
train_dl = DataLoader(train_subjs_bilanciato, batch_size, shuffle=True, num_workers = 0)

val_dl = DataLoader(val_ds, batch_size,  shuffle=True, num_workers = 0)

# %% [markdown]
# ## Funzione per il caricamento nella GPU

# %%
# Controllo della presenza di una GPU
def get_default_device():
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

# Sposta tensori sul device selezionato
def to_device(data, device):
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

# Passa dataloader sul device
class DeviceDataLoader():
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device

    def __iter__(self):
        for b in self.dl:
            yield to_device(b, self.device)

    def __len__(self):
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## Creazione dei DataLoader

# %%
def prepare_batch(batch, device):
    inputs = batch['images'][tio.DATA].to(device)
    #inputs= inputs.reshape(-1,26400)
    labels = batch['OS'].to(device)
    return inputs, labels

# %%
cores = multiprocessing.cpu_count()
batch_size = 6
train_dl = DataLoader(train_ds, batch_size, shuffle = True, num_workers = cores, pin_memory = True)
val_dl = DataLoader(val_ds, batch_size, num_workers = cores, pin_memory = True)

# %% [markdown]
# ## Funzioni di training

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim = 1)
    print('accuracy labels: ', labels)
    print('accuracy preds: ', preds)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

# %%
class_index= 1

# %%
def precision(outputs, labels, class_index):
    _, preds = torch.max(outputs, dim=1) #stiamo assegnando solo l'output degli indici a preds utilizzando l'underscore _ per ignorare l'output dei valori massimi.
    print('\nprecision targets: ', labels)
    print('\nprecision preds: ', preds)



    class_preds = torch.eq(torch.tensor(preds), torch.tensor(class_index))
    class_labels = torch.eq(torch.tensor(labels), torch.tensor(class_index)) #stessa cosa, confronta labels e class index, se sono uguali true(1), diversi false(0)

    true_positives = torch.logical_and(class_preds, class_labels).sum().item() # se label e preds sono 1 allora sono veri positivi
    total_positives = class_preds.sum().item() #tutte le previsioni che ti vengono uguali a 1

    precision = true_positives / total_positives if total_positives != 0 else 0

    return torch.tensor(precision)

# %%
class ImageClassification(nn.Module):
    def training_step(self, batch):
        images = batch['images'][tio.DATA].to(device)
        targets = batch['OS'].to(device)
        out = self(images)
        print('training step targets: ', targets)
        print('training step outputs: ')
        print(out)
        loss = F.cross_entropy(out, targets)
        return loss

    def validation_step(self, batch):
        images = batch['images'][tio.DATA].to(device)
        targets = batch['OS'].to(device)
        out = self(images)
        loss = F.cross_entropy(out, targets)
        acc = accuracy(out, targets)
        prec = precision(out, labels, class_index)
        return {'val_loss': loss.detach(), 'val_acc': acc, 'val_prec': prec}

    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()
        batch_precs = [x['val_prec'] for x in outputs]
        batch_precs = [prec.float() for prec in batch_precs] #AGGIUNTO DOPO PER PROB FLOAT
        epoch_prec = torch.stack(batch_precs).mean()
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item(), 'val_prec': epoch_prec.item()}

    def epoch_end(self, epoch, result):
        print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}, val_prec: {:.4f}".format(
            epoch + 1, result['train_loss'], result['val_loss'], result['val_acc'], result['val_prec']))

# %%
class CNNModel(ImageClassification):
  def __init__(self):
    super().__init__()
    self.network = nn.Sequential(
      # Input: 6 x 30 x 40 x 31
      nn.Conv3d(6, 32, kernel_size = 3, padding = 1),
      # Output: 32 x 30 x 40 x 31
      nn.LeakyReLU(),
      nn.Conv3d(32, 32, kernel_size = 3, stride = 1, padding = 1),
      # Output: 32 x 30 x 40 x 31
      nn.LeakyReLU(),
      nn.MaxPool3d(2),         # Output: immagine con 32 canali e dimensione 15 x 20 x 15 [15 x 20 x 15]

      # Input: 32 x 15 x 20 x 15
      nn.Conv3d(32, 64, kernel_size = 3, stride = 1, padding = 1),
      # Output: 64 x 15 x 20 x 15
      nn.LeakyReLU(),
      nn.Conv3d(64, 64, kernel_size = 3, stride = 1, padding = 1),
      # Output: 64 x 15 x 20 x 15
      nn.LeakyReLU(),
      nn.MaxPool3d(2),         # Output: immagine con 64 canali e dimensione 7 x 10 x 7 [64 x 7 x 10 x 7]

      # Input: 64 x 7 x 10 x 7
      nn.Conv3d(64, 128, kernel_size = 3, stride = 1, padding = 1),
      # Output: 128 x 7 x 10 x 7
      nn.LeakyReLU(),
      nn.Conv3d(128, 128, kernel_size = 3, stride = 1, padding = 1),
      # Output: 128 x 7 x 10 x 7
      nn.LeakyReLU(),
      nn.MaxPool3d(2),         # Output: immagine con 128 canali e dimensione 3 x 5 x 3 [128 x 3 x 5 x 3]

      # Input: 128 x 3 x 5 x 3
      nn.Conv3d(128, 256, kernel_size = 3, stride = 1, padding = 1),
      # Output: 256 x 3 x 5 x 3
      nn.LeakyReLU(),
      nn.Conv3d(256, 256, kernel_size = 3, stride = 1, padding = 1),
      # Output: 256 x 3 x 5 x 3
      nn.LeakyReLU(),
      nn.MaxPool3d(2),         # Output: immagine con 256 canali e dimensione 1 x 2 x 1 [256 x 1 x 2 x 1]

      nn.Flatten(),
      nn.Linear(256 * 1 * 2 * 1, 256),
      nn.LeakyReLU(),
      nn.Linear(256, 64),
      nn.LeakyReLU(),
      nn.Linear(64, 16),
      nn.LeakyReLU(),
      nn.Linear(16, 2)


  )

  def forward(self, xb):
    return self.network(xb)

# %%
device = get_default_device()
model = CNNModel()
to_device(model, device)
# Out:
# CNNModel(
#   (network): Sequential(
#     (0): Conv3d(6, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (6): LeakyReLU(negative_slope=0.01)
#     (7): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (8): LeakyReLU(negative_slope=0.01)
#     (9): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (11): LeakyReLU(negative_slope=0.01)
#     (12): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (13): LeakyReLU(negative_slope=0.01)
#     (14): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv3d(128, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (16): LeakyReLU(negative_slope=0.01)
#     (17): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (18): LeakyReLU(negative_slope=0.01)
#     (19): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (20): Flatten(start_dim=1, end_dim=-1)
#     (21): Linear(in_features=512, out_features=256, bias=True)
#     (22): LeakyReLU(negative_slope=0.01)
#     (23): Linear(in_features=256, out_features=64, bias=True)
#     (24): LeakyReLU(negative_slope=0.01)
#     (25): Linear(in_features=64, out_features=16, bias=True)
#     (26): LeakyReLU(negative_slope=0.01)
#     (27): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %%
for x in train_dl:
    images = x['images'][tio.DATA].to(device)
    targets = x['OS'].to(device)
    print(images)
    print('images.shape:', images.shape)
    out = model(images)
    print('out.shape:', out.shape)
    print('out[0]:', out[0])
    break
# Out:
# tensor([[[[[-3.3447, -3.3447, -3.3447,  ..., -3.3447, -3.3447, -3.3447],
#            [-3.3447, -3.3447, -3.3447,  ..., -3.3447, -3.3447, -3.3447],
#            [-3.3447, -3.3447, -3.3447,  ..., -3.3447, -3.3447, -3.3447],
#            ...,
#            [-3.3447, -3.3447, -3.3447,  ..., -3.3447, -3.3447, -3.3447],
#            [-3.3447, -3.3447, -3.3447,  ..., -3.3447, -3.3447, -3.3447],
#            [-3.3447, -3.3447, -3.3447,  ..., -3.3447, -3.3447, -3.3447]],
#
#           [[-3.3447, -3.3447, -3.3447,  ..., -3.3447, -3.3447, -3.3447],
#            [-3.3447, -3.3447, -3.3447,  ..., -3.3447, -3.3447, -3.3447],
#            [-3.3447, -3.3447, -3.3447,  ..., -3.3447, -3.3447, -3.3447],
#            ...,
#            [-3.3447, -3.3447, -3.3447,  ..., -3.3447, -3.3447, -3.3447],
#            [-3.3447, -3.3447, -3.3447,  ..., -3.3447, -3.3447, -3.3447],
#            [-3.3447, -3.3447, -3.3447,  ..., -3.3447, -3.3447, -3.3447]],
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589]],
#
#           ...,
#
#           [[-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            ...,
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589]],
#
#           [[-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            ...,
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589]],
#
#           [[-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            ...,
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589],
#            [-0.8589, -0.8589, -0.8589,  ..., -0.8589, -0.8589, -0.8589]]],
#
#
#          [[[-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            ...,
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289]],
#
#           [[-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            ...,
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289]],
#
#           [[-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            ...,
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289]],
#
#           ...,
#
#           [[-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            ...,
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289]],
#
#           [[-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            ...,
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289]],
#
#           [[-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            ...,
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289],
#            [-2.0289, -2.0289, -2.0289,  ..., -2.0289, -2.0289, -2.0289]]]]])
# images.shape: torch.Size([6, 6, 30, 40, 31])
# out.shape: torch.Size([6, 2])
# out[0]: tensor([0.1615, 0.1915], grad_fn=<SelectBackward0>)

# %%
#PROVO A TOGLIERE MODEL.EVAL()
@torch.no_grad()                    # Bisogna inserirlo prima di un evaluator per specificare che non vogliamo fare gradient descent
def evaluate(model, val_loader):
    model.eval()                    # Comunica a Pytorch di entrare in "modo evaluation" (layer viene "congelato" e non si ha randomization)
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.SGD):
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase
        model.train()                               # Comunica a Pytorch che sta facendo il training
        train_losses = []
        for batch in train_loader:
            loss = model.training_step(batch)
            train_losses.append(loss)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, val_loader)
        result['train_loss'] = torch.stack(train_losses).mean().item()
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
evaluate(model, val_dl)
# Out:
# accuracy labels:  tensor([0, 0, 1, 0, 0, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# <ipython-input-28-3f3c149a10c5>:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   class_preds = torch.eq(torch.tensor(preds), torch.tensor(class_index))
# accuracy labels:  tensor([0, 0, 1, 1, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 1, 0, 1, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([1, 1, 0, 0, 1, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 0, 1, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 1, 1, 0, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 1, 1, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 0, 0, 0, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0])
# accuracy preds:  tensor([1])
#
# precision targets:  1
#
# precision preds:  tensor([1])
# {'val_loss': 0.6974327564239502,
#  'val_acc': 0.3611110746860504,
#  'val_prec': 1.0}

# %%
#num_epochs = 10
opt_func = torch.optim.SGD
#lr = 0.1

# %%
history = fit(10, 0.0001, model, train_dl, val_dl, opt_func)
# Out:
# training step targets:  tensor([0, 0, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 0, 1, 1])
# training step outputs:
# tensor([[0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1914],
#         [0.1615, 0.1915]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 1, 0])
# training step outputs:
# tensor([[0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 1, 1, 1])
# training step outputs:
# tensor([[0.1615, 0.1914],
#         [0.1615, 0.1914],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1914],
#         [0.1615, 0.1915]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 0, 1, 1])
# training step outputs:
# tensor([[0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915],
#         [0.1615, 0.1915]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1615, 0.1914],
#         [0.1615, 0.1914],
#         [0.1615, 0.1914],
#         [0.1615, 0.1914],
#         [0.1615, 0.1914],
#         [0.1615, 0.1914]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1615, 0.1914],
#         [0.1615, 0.1914],
#         [0.1615, 0.1914],
#         [0.1615, 0.1915],
#         [0.1615, 0.1914],
#         [0.1616, 0.1914]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 1, 0])
# training step outputs:
# tensor([[0.1616, 0.1914],
#         [0.1616, 0.1914],
#         [0.1616, 0.1914],
#         [0.1616, 0.1914],
#         [0.1616, 0.1914],
#         [0.1616, 0.1914]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1616, 0.1914],
#         [0.1616, 0.1914],
#         [0.1616, 0.1914],
#         [0.1616, 0.1914],
#         [0.1616, 0.1914],
#         [0.1616, 0.1914]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1616, 0.1914],
#         [0.1616, 0.1914],
#         [0.1616, 0.1914],
#         [0.1616, 0.1914],
#         [0.1616, 0.1914],
#         [0.1616, 0.1914]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1617, 0.1913],
#         [0.1617, 0.1913],
#         [0.1617, 0.1913],
#         [0.1617, 0.1913],
#         [0.1617, 0.1913],
#         [0.1617, 0.1913]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1617, 0.1913],
#         [0.1617, 0.1913],
#         [0.1617, 0.1913],
#         [0.1617, 0.1913],
#         [0.1617, 0.1913],
#         [0.1617, 0.1913]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1618, 0.1913],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1913],
#         [0.1617, 0.1913],
#         [0.1618, 0.1912]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 1, 1, 0, 0])
# training step outputs:
# tensor([[0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1913],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 1, 0, 1, 0])
# training step outputs:
# tensor([[0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 1, 1])
# training step outputs:
# tensor([[0.1619, 0.1912],
#         [0.1619, 0.1912],
#         [0.1619, 0.1912],
#         [0.1619, 0.1912],
#         [0.1618, 0.1912],
#         [0.1619, 0.1912]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1619, 0.1912],
#         [0.1619, 0.1912],
#         [0.1618, 0.1912],
#         [0.1619, 0.1912],
#         [0.1618, 0.1912],
#         [0.1618, 0.1912]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 1, 1, 1])
# training step outputs:
# tensor([[0.1619, 0.1911],
#         [0.1619, 0.1911],
#         [0.1619, 0.1911],
#         [0.1619, 0.1911],
#         [0.1619, 0.1911],
#         [0.1619, 0.1911]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1619, 0.1911],
#         [0.1619, 0.1911],
#         [0.1619, 0.1911],
#         [0.1619, 0.1911],
#         [0.1619, 0.1911],
#         [0.1619, 0.1911]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1619, 0.1911],
#         [0.1619, 0.1911],
#         [0.1619, 0.1911],
#         [0.1619, 0.1911],
#         [0.1619, 0.1911],
#         [0.1619, 0.1911]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1620, 0.1911],
#         [0.1620, 0.1911],
#         [0.1620, 0.1911],
#         [0.1620, 0.1910],
#         [0.1620, 0.1911],
#         [0.1620, 0.1911]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 1, 1, 0])
# training step outputs:
# tensor([[0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 1, 1])
# training step outputs:
# tensor([[0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1621, 0.1909],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 1, 0, 1])
# training step outputs:
# tensor([[0.1621, 0.1910],
#         [0.1620, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 1, 1])
# training step outputs:
# tensor([[0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 1, 1, 0])
# training step outputs:
# tensor([[0.1621, 0.1910],
#         [0.1620, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 1, 0])
# training step outputs:
# tensor([[0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1621, 0.1909],
#         [0.1621, 0.1909],
#         [0.1621, 0.1909],
#         [0.1621, 0.1909],
#         [0.1621, 0.1909],
#         [0.1621, 0.1909]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 1, 0, 1])
# training step outputs:
# tensor([[0.1621, 0.1909],
#         [0.1621, 0.1909],
#         [0.1621, 0.1909],
#         [0.1621, 0.1909],
#         [0.1621, 0.1909],
#         [0.1621, 0.1909]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 1, 1, 1, 0])
# training step outputs:
# tensor([[0.1621, 0.1909],
#         [0.1621, 0.1909],
#         [0.1621, 0.1909],
#         [0.1621, 0.1909],
#         [0.1621, 0.1909],
#         [0.1621, 0.1909]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 0, 1, 1])
# training step outputs:
# tensor([[0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 1, 0])
# training step outputs:
# tensor([[0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 1, 1, 0])
# training step outputs:
# tensor([[0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910]], grad_fn=<AddmmBackward0>)
# accuracy labels:  tensor([0, 0, 1, 0, 0, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# <ipython-input-28-3f3c149a10c5>:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   class_preds = torch.eq(torch.tensor(preds), torch.tensor(class_index))
# accuracy labels:  tensor([0, 0, 1, 1, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 1, 0, 1, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([1, 1, 0, 0, 1, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 0, 1, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 1, 1, 0, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 1, 1, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 0, 0, 0, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0])
# accuracy preds:  tensor([1])
#
# precision targets:  1
#
# precision preds:  tensor([1])
# Epoch [1], train_loss: 0.6963, val_loss: 0.6973, val_acc: 0.3611, val_prec: 1.0000
# training step targets:  tensor([0, 0, 1, 0, 1, 1])
# training step outputs:
# tensor([[0.1620, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 1, 1, 1, 0])
# training step outputs:
# tensor([[0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1620, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 1, 1, 0])
# training step outputs:
# tensor([[0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1620, 0.1911],
#         [0.1620, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1620, 0.1911],
#         [0.1620, 0.1911],
#         [0.1620, 0.1911],
#         [0.1620, 0.1911],
#         [0.1620, 0.1911],
#         [0.1620, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1620, 0.1911],
#         [0.1620, 0.1911],
#         [0.1620, 0.1911],
#         [0.1620, 0.1910],
#         [0.1619, 0.1911],
#         [0.1620, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 1, 1, 1])
# training step outputs:
# tensor([[0.1620, 0.1911],
#         [0.1620, 0.1911],
#         [0.1620, 0.1911],
#         [0.1620, 0.1910],
#         [0.1620, 0.1910],
#         [0.1619, 0.1911]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1619, 0.1911],
#         [0.1620, 0.1911],
#         [0.1620, 0.1911],
#         [0.1620, 0.1911],
#         [0.1619, 0.1911],
#         [0.1619, 0.1911]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 1, 0])
# training step outputs:
# tensor([[0.1619, 0.1911],
#         [0.1620, 0.1911],
#         [0.1619, 0.1911],
#         [0.1619, 0.1911],
#         [0.1619, 0.1911],
#         [0.1619, 0.1911]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1620, 0.1911],
#         [0.1620, 0.1910],
#         [0.1620, 0.1911],
#         [0.1620, 0.1911],
#         [0.1620, 0.1910],
#         [0.1620, 0.1911]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1620, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1620, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910],
#         [0.1621, 0.1910]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1621, 0.1909],
#         [0.1622, 0.1909],
#         [0.1621, 0.1909],
#         [0.1621, 0.1909],
#         [0.1622, 0.1909],
#         [0.1621, 0.1909]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 0, 1, 0])
# training step outputs:
# tensor([[0.1622, 0.1909],
#         [0.1622, 0.1908],
#         [0.1622, 0.1909],
#         [0.1622, 0.1908],
#         [0.1622, 0.1908],
#         [0.1622, 0.1908]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1622, 0.1908],
#         [0.1622, 0.1909],
#         [0.1622, 0.1909],
#         [0.1622, 0.1908],
#         [0.1622, 0.1908],
#         [0.1622, 0.1909]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1622, 0.1908],
#         [0.1622, 0.1909],
#         [0.1622, 0.1909],
#         [0.1622, 0.1909],
#         [0.1622, 0.1908],
#         [0.1622, 0.1908]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1622, 0.1908],
#         [0.1622, 0.1908],
#         [0.1622, 0.1908],
#         [0.1622, 0.1908],
#         [0.1622, 0.1908],
#         [0.1622, 0.1908]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 1, 1])
# training step outputs:
# tensor([[0.1623, 0.1908],
#         [0.1623, 0.1908],
#         [0.1623, 0.1908],
#         [0.1622, 0.1908],
#         [0.1623, 0.1908],
#         [0.1623, 0.1908]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 1, 1, 0])
# training step outputs:
# tensor([[0.1622, 0.1908],
#         [0.1622, 0.1908],
#         [0.1623, 0.1908],
#         [0.1623, 0.1908],
#         [0.1623, 0.1908],
#         [0.1623, 0.1908]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1622, 0.1908],
#         [0.1622, 0.1908],
#         [0.1622, 0.1908],
#         [0.1622, 0.1908],
#         [0.1622, 0.1908],
#         [0.1622, 0.1908]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1623, 0.1908],
#         [0.1623, 0.1908],
#         [0.1623, 0.1908],
#         [0.1623, 0.1908],
#         [0.1623, 0.1908],
#         [0.1623, 0.1908]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 1, 1])
# training step outputs:
# tensor([[0.1624, 0.1907],
#         [0.1623, 0.1907],
#         [0.1624, 0.1907],
#         [0.1623, 0.1907],
#         [0.1623, 0.1907],
#         [0.1623, 0.1907]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1623, 0.1907],
#         [0.1623, 0.1907],
#         [0.1624, 0.1907],
#         [0.1624, 0.1907],
#         [0.1624, 0.1907],
#         [0.1624, 0.1907]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 1, 0])
# training step outputs:
# tensor([[0.1624, 0.1907],
#         [0.1624, 0.1907],
#         [0.1624, 0.1907],
#         [0.1624, 0.1907],
#         [0.1624, 0.1907],
#         [0.1624, 0.1907]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1624, 0.1907],
#         [0.1624, 0.1907],
#         [0.1624, 0.1907],
#         [0.1624, 0.1907],
#         [0.1624, 0.1907],
#         [0.1624, 0.1907]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 0, 1, 0])
# training step outputs:
# tensor([[0.1624, 0.1906],
#         [0.1624, 0.1906],
#         [0.1624, 0.1906],
#         [0.1624, 0.1906],
#         [0.1625, 0.1906],
#         [0.1624, 0.1906]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1624, 0.1906],
#         [0.1624, 0.1906],
#         [0.1624, 0.1906],
#         [0.1624, 0.1906],
#         [0.1625, 0.1906],
#         [0.1625, 0.1906]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1625, 0.1906],
#         [0.1625, 0.1906],
#         [0.1625, 0.1906],
#         [0.1625, 0.1906],
#         [0.1625, 0.1906],
#         [0.1625, 0.1906]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1625, 0.1906],
#         [0.1625, 0.1906],
#         [0.1625, 0.1906],
#         [0.1625, 0.1906],
#         [0.1625, 0.1906],
#         [0.1625, 0.1906]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1625, 0.1905],
#         [0.1625, 0.1905],
#         [0.1625, 0.1905],
#         [0.1625, 0.1906],
#         [0.1625, 0.1905],
#         [0.1625, 0.1905]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 0, 1, 0])
# training step outputs:
# tensor([[0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 1, 1])
# training step outputs:
# tensor([[0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 1, 1, 1, 0])
# training step outputs:
# tensor([[0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 1, 1, 0])
# training step outputs:
# tensor([[0.1627, 0.1904],
#         [0.1627, 0.1904],
#         [0.1627, 0.1904],
#         [0.1627, 0.1905],
#         [0.1627, 0.1904],
#         [0.1627, 0.1904]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 1, 1, 0])
# training step outputs:
# tensor([[0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905]], grad_fn=<AddmmBackward0>)
# accuracy labels:  tensor([0, 0, 1, 0, 0, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 1, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 1, 0, 1, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([1, 1, 0, 0, 1, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 0, 1, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 1, 1, 0, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 1, 1, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 0, 0, 0, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0])
# accuracy preds:  tensor([1])
#
# precision targets:  1
#
# precision preds:  tensor([1])
# Epoch [2], train_loss: 0.6962, val_loss: 0.6971, val_acc: 0.3611, val_prec: 1.0000
# training step targets:  tensor([1, 0, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1627, 0.1905],
#         [0.1627, 0.1905],
#         [0.1627, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905],
#         [0.1626, 0.1905]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 1, 0, 1])
# training step outputs:
# tensor([[0.1627, 0.1904],
#         [0.1627, 0.1905],
#         [0.1627, 0.1904],
#         [0.1627, 0.1904],
#         [0.1627, 0.1904],
#         [0.1627, 0.1904]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1627, 0.1904],
#         [0.1627, 0.1904],
#         [0.1627, 0.1904],
#         [0.1627, 0.1904],
#         [0.1627, 0.1904],
#         [0.1627, 0.1905]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 1, 1, 1])
# training step outputs:
# tensor([[0.1627, 0.1904],
#         [0.1627, 0.1904],
#         [0.1627, 0.1904],
#         [0.1627, 0.1904],
#         [0.1627, 0.1904],
#         [0.1627, 0.1904]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1627, 0.1904],
#         [0.1627, 0.1904],
#         [0.1627, 0.1904],
#         [0.1627, 0.1904],
#         [0.1627, 0.1904],
#         [0.1627, 0.1904]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1628, 0.1904],
#         [0.1628, 0.1903],
#         [0.1628, 0.1904],
#         [0.1628, 0.1904],
#         [0.1628, 0.1904],
#         [0.1628, 0.1904]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1628, 0.1903],
#         [0.1628, 0.1903],
#         [0.1628, 0.1903],
#         [0.1628, 0.1903],
#         [0.1628, 0.1903],
#         [0.1628, 0.1903]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1628, 0.1903],
#         [0.1628, 0.1903],
#         [0.1628, 0.1903],
#         [0.1628, 0.1903],
#         [0.1628, 0.1903],
#         [0.1628, 0.1903]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1628, 0.1903],
#         [0.1628, 0.1903],
#         [0.1628, 0.1903],
#         [0.1628, 0.1903],
#         [0.1628, 0.1903],
#         [0.1628, 0.1903]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 1, 0, 0])
# training step outputs:
# tensor([[0.1629, 0.1902],
#         [0.1629, 0.1903],
#         [0.1629, 0.1903],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1903]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 0, 1, 1])
# training step outputs:
# tensor([[0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1903],
#         [0.1629, 0.1902]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 1, 1])
# training step outputs:
# tensor([[0.1629, 0.1903],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1903],
#         [0.1629, 0.1903]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1903],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 1, 0, 1, 0])
# training step outputs:
# tensor([[0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 1, 0, 0])
# training step outputs:
# tensor([[0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 0, 1])
# training step outputs:
# tensor([[0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 1, 1, 1])
# training step outputs:
# tensor([[0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 0, 1, 0])
# training step outputs:
# tensor([[0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1903]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 0, 1])
# training step outputs:
# tensor([[0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1903],
#         [0.1629, 0.1903]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902],
#         [0.1629, 0.1902]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1630, 0.1902],
#         [0.1630, 0.1902],
#         [0.1630, 0.1902],
#         [0.1630, 0.1902],
#         [0.1630, 0.1902],
#         [0.1630, 0.1902]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 1, 0])
# training step outputs:
# tensor([[0.1630, 0.1902],
#         [0.1630, 0.1902],
#         [0.1630, 0.1902],
#         [0.1630, 0.1902],
#         [0.1630, 0.1902],
#         [0.1630, 0.1902]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 1, 1])
# training step outputs:
# tensor([[0.1630, 0.1901],
#         [0.1630, 0.1902],
#         [0.1630, 0.1901],
#         [0.1630, 0.1901],
#         [0.1630, 0.1902],
#         [0.1630, 0.1901]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1630, 0.1901],
#         [0.1630, 0.1901],
#         [0.1630, 0.1901],
#         [0.1630, 0.1901],
#         [0.1630, 0.1901],
#         [0.1630, 0.1901]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1631, 0.1901],
#         [0.1631, 0.1901],
#         [0.1631, 0.1901],
#         [0.1631, 0.1901],
#         [0.1631, 0.1900],
#         [0.1631, 0.1901]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1631, 0.1901],
#         [0.1631, 0.1901],
#         [0.1631, 0.1901],
#         [0.1631, 0.1901],
#         [0.1631, 0.1901],
#         [0.1631, 0.1901]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1631, 0.1900],
#         [0.1632, 0.1900]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 1, 0, 1])
# training step outputs:
# tensor([[0.1632, 0.1899],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1899],
#         [0.1632, 0.1899],
#         [0.1632, 0.1899]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 1, 1, 1, 0])
# training step outputs:
# tensor([[0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 0, 1, 1])
# training step outputs:
# tensor([[0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1632, 0.1900],
#         [0.1632, 0.1899],
#         [0.1632, 0.1899],
#         [0.1632, 0.1900],
#         [0.1632, 0.1899],
#         [0.1632, 0.1900]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 1, 1, 1, 1])
# training step outputs:
# tensor([[0.1633, 0.1898],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 1, 0, 1, 1])
# training step outputs:
# tensor([[0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899]], grad_fn=<AddmmBackward0>)
# accuracy labels:  tensor([0, 0, 1, 0, 0, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 1, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 1, 0, 1, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([1, 1, 0, 0, 1, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 0, 1, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 1, 1, 0, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 1, 1, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 0, 0, 0, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0])
# accuracy preds:  tensor([1])
#
# precision targets:  1
#
# precision preds:  tensor([1])
# Epoch [3], train_loss: 0.6960, val_loss: 0.6969, val_acc: 0.3611, val_prec: 1.0000
# training step targets:  tensor([0, 1, 1, 1, 0, 0])
# training step outputs:
# tensor([[0.1632, 0.1899],
#         [0.1632, 0.1899],
#         [0.1632, 0.1899],
#         [0.1632, 0.1899],
#         [0.1632, 0.1899],
#         [0.1632, 0.1900]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 1, 0])
# training step outputs:
# tensor([[0.1633, 0.1899],
#         [0.1632, 0.1900],
#         [0.1632, 0.1899],
#         [0.1632, 0.1899],
#         [0.1632, 0.1900],
#         [0.1632, 0.1899]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 1, 0, 1, 0])
# training step outputs:
# tensor([[0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 1, 1, 1])
# training step outputs:
# tensor([[0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 1, 1, 1])
# training step outputs:
# tensor([[0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 0, 1, 1])
# training step outputs:
# tensor([[0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1899],
#         [0.1632, 0.1900],
#         [0.1632, 0.1899],
#         [0.1632, 0.1899]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900],
#         [0.1632, 0.1900]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1632, 0.1899],
#         [0.1632, 0.1899],
#         [0.1632, 0.1899],
#         [0.1632, 0.1899],
#         [0.1632, 0.1899],
#         [0.1632, 0.1899]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 1, 1, 0, 0])
# training step outputs:
# tensor([[0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 0, 1, 1])
# training step outputs:
# tensor([[0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899],
#         [0.1633, 0.1899]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1633, 0.1899],
#         [0.1633, 0.1898],
#         [0.1633, 0.1899],
#         [0.1633, 0.1898],
#         [0.1634, 0.1898],
#         [0.1633, 0.1899]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1633, 0.1898],
#         [0.1634, 0.1898],
#         [0.1634, 0.1898],
#         [0.1634, 0.1898],
#         [0.1634, 0.1898],
#         [0.1634, 0.1898]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1634, 0.1898],
#         [0.1634, 0.1898],
#         [0.1634, 0.1898],
#         [0.1634, 0.1898],
#         [0.1634, 0.1898],
#         [0.1634, 0.1898]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1634, 0.1898],
#         [0.1634, 0.1898],
#         [0.1634, 0.1898],
#         [0.1634, 0.1898],
#         [0.1634, 0.1898],
#         [0.1634, 0.1898]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1635, 0.1897],
#         [0.1634, 0.1897],
#         [0.1635, 0.1897],
#         [0.1635, 0.1898],
#         [0.1635, 0.1897],
#         [0.1635, 0.1897]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 1, 1])
# training step outputs:
# tensor([[0.1635, 0.1897],
#         [0.1635, 0.1897],
#         [0.1634, 0.1897],
#         [0.1635, 0.1898],
#         [0.1634, 0.1898],
#         [0.1635, 0.1897]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1635, 0.1897],
#         [0.1635, 0.1898],
#         [0.1635, 0.1897],
#         [0.1634, 0.1897],
#         [0.1634, 0.1897],
#         [0.1635, 0.1897]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1635, 0.1897],
#         [0.1635, 0.1897],
#         [0.1635, 0.1897],
#         [0.1635, 0.1897],
#         [0.1635, 0.1897],
#         [0.1635, 0.1897]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 0, 1])
# training step outputs:
# tensor([[0.1635, 0.1897],
#         [0.1635, 0.1897],
#         [0.1635, 0.1897],
#         [0.1635, 0.1897],
#         [0.1636, 0.1897],
#         [0.1635, 0.1897]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 1, 0, 0])
# training step outputs:
# tensor([[0.1636, 0.1896],
#         [0.1636, 0.1896],
#         [0.1636, 0.1897],
#         [0.1636, 0.1897],
#         [0.1636, 0.1896],
#         [0.1635, 0.1897]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 1, 0])
# training step outputs:
# tensor([[0.1636, 0.1896],
#         [0.1636, 0.1896],
#         [0.1636, 0.1896],
#         [0.1636, 0.1896],
#         [0.1636, 0.1896],
#         [0.1636, 0.1896]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 1, 0, 0])
# training step outputs:
# tensor([[0.1636, 0.1896],
#         [0.1636, 0.1896],
#         [0.1636, 0.1896],
#         [0.1636, 0.1896],
#         [0.1636, 0.1896],
#         [0.1636, 0.1896]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1636, 0.1896],
#         [0.1636, 0.1896],
#         [0.1636, 0.1896],
#         [0.1636, 0.1896],
#         [0.1636, 0.1896],
#         [0.1636, 0.1896]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 1, 0])
# training step outputs:
# tensor([[0.1636, 0.1896],
#         [0.1636, 0.1896],
#         [0.1636, 0.1896],
#         [0.1636, 0.1896],
#         [0.1637, 0.1896],
#         [0.1636, 0.1896]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1896],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 1, 0])
# training step outputs:
# tensor([[0.1638, 0.1895],
#         [0.1638, 0.1895],
#         [0.1638, 0.1895],
#         [0.1638, 0.1895],
#         [0.1638, 0.1895],
#         [0.1638, 0.1895]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 1, 0])
# training step outputs:
# tensor([[0.1638, 0.1894],
#         [0.1638, 0.1895],
#         [0.1638, 0.1895],
#         [0.1638, 0.1894],
#         [0.1638, 0.1895],
#         [0.1638, 0.1895]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 1, 0, 1, 0])
# training step outputs:
# tensor([[0.1638, 0.1894],
#         [0.1638, 0.1894],
#         [0.1638, 0.1894],
#         [0.1638, 0.1894],
#         [0.1638, 0.1894],
#         [0.1638, 0.1894]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 1, 1, 1, 1])
# training step outputs:
# tensor([[0.1638, 0.1894],
#         [0.1638, 0.1895],
#         [0.1638, 0.1894],
#         [0.1638, 0.1895],
#         [0.1638, 0.1895],
#         [0.1638, 0.1895]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 0, 1, 1])
# training step outputs:
# tensor([[0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 0, 1])
# training step outputs:
# tensor([[0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 1, 0])
# training step outputs:
# tensor([[0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 0, 1, 1])
# training step outputs:
# tensor([[0.1637, 0.1895],
#         [0.1638, 0.1895],
#         [0.1637, 0.1895],
#         [0.1638, 0.1895],
#         [0.1637, 0.1895],
#         [0.1637, 0.1895]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1637, 0.1895],
#         [0.1638, 0.1895],
#         [0.1638, 0.1895],
#         [0.1637, 0.1895],
#         [0.1638, 0.1895],
#         [0.1637, 0.1895]], grad_fn=<AddmmBackward0>)
# accuracy labels:  tensor([0, 0, 1, 0, 0, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 1, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 1, 0, 1, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([1, 1, 0, 0, 1, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 0, 1, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 1, 1, 0, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 1, 1, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 0, 0, 0, 0])
# ...
# training step targets:  tensor([0, 1, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1665, 0.1870],
#         [0.1666, 0.1870],
#         [0.1665, 0.1870],
#         [0.1665, 0.1870],
#         [0.1665, 0.1870],
#         [0.1665, 0.1870]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 1, 1])
# training step outputs:
# tensor([[0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870],
#         [0.1666, 0.1870]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1667, 0.1869],
#         [0.1667, 0.1869],
#         [0.1667, 0.1869],
#         [0.1667, 0.1869],
#         [0.1667, 0.1869],
#         [0.1666, 0.1869]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1667, 0.1869],
#         [0.1667, 0.1869],
#         [0.1667, 0.1869],
#         [0.1667, 0.1869],
#         [0.1667, 0.1869],
#         [0.1667, 0.1869]], grad_fn=<AddmmBackward0>)
# accuracy labels:  tensor([0, 0, 1, 0, 0, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 1, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 1, 0, 1, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([1, 1, 0, 0, 1, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 0, 1, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 1, 1, 0, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 1, 1, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 0, 0, 0, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0])
# accuracy preds:  tensor([1])
#
# precision targets:  1
#
# precision preds:  tensor([1])
# Epoch [9], train_loss: 0.6953, val_loss: 0.6960, val_acc: 0.3611, val_prec: 1.0000
# training step targets:  tensor([0, 1, 0, 1, 1, 1])
# training step outputs:
# tensor([[0.1667, 0.1869],
#         [0.1667, 0.1869],
#         [0.1667, 0.1869],
#         [0.1667, 0.1869],
#         [0.1667, 0.1869],
#         [0.1667, 0.1869]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1667, 0.1869],
#         [0.1667, 0.1869],
#         [0.1667, 0.1869],
#         [0.1667, 0.1869],
#         [0.1667, 0.1869],
#         [0.1667, 0.1869]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 1, 0, 1])
# training step outputs:
# tensor([[0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 1, 1, 1, 1])
# training step outputs:
# tensor([[0.1669, 0.1867],
#         [0.1669, 0.1868],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 1, 0])
# training step outputs:
# tensor([[0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868],
#         [0.1668, 0.1868]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 1, 1])
# training step outputs:
# tensor([[0.1670, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 1, 1, 1, 0])
# training step outputs:
# tensor([[0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1670, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 1, 0])
# training step outputs:
# tensor([[0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867],
#         [0.1669, 0.1867]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1670, 0.1866],
#         [0.1670, 0.1867],
#         [0.1670, 0.1866],
#         [0.1669, 0.1867],
#         [0.1670, 0.1866],
#         [0.1670, 0.1867]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1670, 0.1866],
#         [0.1670, 0.1866],
#         [0.1670, 0.1866],
#         [0.1670, 0.1866],
#         [0.1670, 0.1866],
#         [0.1670, 0.1866]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1670, 0.1866],
#         [0.1670, 0.1866],
#         [0.1670, 0.1866],
#         [0.1670, 0.1866],
#         [0.1670, 0.1866],
#         [0.1670, 0.1866]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 1, 0, 0])
# training step outputs:
# tensor([[0.1671, 0.1866],
#         [0.1671, 0.1866],
#         [0.1671, 0.1866],
#         [0.1671, 0.1866],
#         [0.1671, 0.1866],
#         [0.1671, 0.1866]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 0, 0, 1])
# training step outputs:
# tensor([[0.1671, 0.1866],
#         [0.1671, 0.1866],
#         [0.1671, 0.1866],
#         [0.1671, 0.1866],
#         [0.1671, 0.1866],
#         [0.1670, 0.1866]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 1, 0])
# training step outputs:
# tensor([[0.1671, 0.1866],
#         [0.1671, 0.1866],
#         [0.1671, 0.1866],
#         [0.1671, 0.1866],
#         [0.1671, 0.1866],
#         [0.1671, 0.1866]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 1, 1, 1])
# training step outputs:
# tensor([[0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1671, 0.1866],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 0, 1, 0])
# training step outputs:
# tensor([[0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 0, 0, 0])
# training step outputs:
# tensor([[0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 0, 0, 1, 0])
# training step outputs:
# tensor([[0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1672, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 0, 1])
# training step outputs:
# tensor([[0.1672, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865],
#         [0.1671, 0.1865]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 1, 0])
# training step outputs:
# tensor([[0.1672, 0.1865],
#         [0.1672, 0.1865],
#         [0.1671, 0.1865],
#         [0.1672, 0.1865],
#         [0.1672, 0.1865],
#         [0.1672, 0.1865]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 1, 0, 1, 1])
# training step outputs:
# tensor([[0.1672, 0.1864],
#         [0.1672, 0.1864],
#         [0.1672, 0.1864],
#         [0.1672, 0.1864],
#         [0.1672, 0.1864],
#         [0.1672, 0.1864]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 0, 1, 1, 0])
# training step outputs:
# tensor([[0.1672, 0.1864],
#         [0.1672, 0.1864],
#         [0.1672, 0.1864],
#         [0.1672, 0.1864],
#         [0.1672, 0.1864],
#         [0.1672, 0.1864]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 1, 1, 0])
# training step outputs:
# tensor([[0.1672, 0.1864],
#         [0.1672, 0.1864],
#         [0.1672, 0.1865],
#         [0.1672, 0.1864],
#         [0.1672, 0.1864],
#         [0.1672, 0.1864]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 0, 0, 0])
# training step outputs:
# tensor([[0.1672, 0.1864],
#         [0.1672, 0.1864],
#         [0.1672, 0.1864],
#         [0.1672, 0.1864],
#         [0.1672, 0.1864],
#         [0.1672, 0.1864]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 0, 0, 1, 1, 0])
# training step outputs:
# tensor([[0.1673, 0.1864],
#         [0.1673, 0.1864],
#         [0.1673, 0.1864],
#         [0.1673, 0.1864],
#         [0.1673, 0.1864],
#         [0.1673, 0.1864]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([0, 1, 1, 0, 1, 0])
# training step outputs:
# tensor([[0.1673, 0.1864],
#         [0.1673, 0.1864],
#         [0.1673, 0.1863],
#         [0.1673, 0.1863],
#         [0.1673, 0.1864],
#         [0.1673, 0.1863]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 0, 0, 1, 0, 0])
# training step outputs:
# tensor([[0.1673, 0.1864],
#         [0.1673, 0.1864],
#         [0.1673, 0.1864],
#         [0.1673, 0.1864],
#         [0.1673, 0.1864],
#         [0.1673, 0.1863]], grad_fn=<AddmmBackward0>)
# training step targets:  tensor([1, 1, 1, 0, 0, 1])
# training step outputs:
# tensor([[0.1673, 0.1863],
#         [0.1673, 0.1863],
#         [0.1673, 0.1863],
#         [0.1673, 0.1863],
#         [0.1673, 0.1863],
#         [0.1673, 0.1863]], grad_fn=<AddmmBackward0>)
# accuracy labels:  tensor([0, 0, 1, 0, 0, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 1, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 1, 0, 1, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([1, 1, 0, 0, 1, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 0, 1, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 1, 1, 0, 0, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 0, 1, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 1, 1, 1, 1])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0, 0, 0, 0, 0, 0])
# accuracy preds:  tensor([1, 1, 1, 1, 1, 1])
#
# precision targets:  1
#
# precision preds:  tensor([1, 1, 1, 1, 1, 1])
# accuracy labels:  tensor([0])
# accuracy preds:  tensor([1])
#
# precision targets:  1
#
# precision preds:  tensor([1])
# Epoch [10], train_loss: 0.6952, val_loss: 0.6958, val_acc: 0.3611, val_prec: 1.0000

# %%
#history = fit(11, 0.001, model, train_dl, val_dl, opt_func)

# %%
#history = fit(5, 0.0001, model, train_dl, val_dl, opt_func)

# %%
losses = [x['val_loss'] for x in history]
plt.plot(losses, '-x')
plt.xlabel('Epoche')
plt.ylabel('Val_loss')
plt.title('Val_loss vs. No. di Epoche')
# Out:
# Text(0.5, 1.0, 'Val_loss vs. No. di Epoche')

# %%
accuracies = [x['val_acc'] for x in history]
plt.plot(accuracies, '-x')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title('Accuracy vs. No. of epochs');

# %%
precision = [x['val_prec'] for x in history]
plt.plot(precision, '-x')
plt.xlabel('epoch')
plt.ylabel('precision')
plt.title('precision vs. No. of epochs');
